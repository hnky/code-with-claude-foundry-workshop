# %% [markdown]
# # 💻 Code Generation & Analysis with Claude Sonnet 4.6
#
# Welcome to **LegacyBridge Financial**, a fictional financial services company modernizing a 20-year-old trading platform spread across **Java and COBOL**. The system still clears millions of transactions a day, but the CTO has greenlit a modernization push: translate legacy logic to Python, review risky code, generate comprehensive tests, and automate Azure infrastructure.
#
# In this notebook, you'll use **Claude Sonnet 4.6 on Microsoft Foundry** like an experienced engineering partner for modernization work.
#
# ### What you'll learn
# - Generate production-style code from detailed specifications
# - Review and debug code for bugs, security issues, and design flaws
# - Translate legacy code into modern Python
# - Generate tests to build confidence before refactoring
# - Use multi-turn sessions for iterative refinement
# - Generate Infrastructure as Code (IaC) for Azure deployments

# %%
import os

from dotenv import load_dotenv

from agent_framework import Agent
from agent_framework.anthropic import AnthropicChatOptions
from agent_framework.foundry import AnthropicFoundryClient

load_dotenv(dotenv_path="../.env")

chat_client = AnthropicFoundryClient(
    model=os.environ["FOUNDRY_MODEL_DEPLOYMENT"],
    api_key=os.environ["FOUNDRY_API_KEY"],
    base_url=os.environ["FOUNDRY_ENDPOINT"],
)

agent = Agent(
    client=chat_client,
    name="code-assistant",
    instructions=(
        "You are a senior software engineer and code architect with expertise in "
        "Python, Java, COBOL, cloud infrastructure (Terraform, Bicep), and "
        "software testing. When writing code: include docstrings, type hints, "
        "error handling, and follow best practices. When reviewing code: identify "
        "bugs, security issues, performance problems, and suggest specific fixes."
    ),
    default_options=AnthropicChatOptions(max_tokens=4096, temperature=0.0),
)

setup_session = agent.create_session()
response = await agent.run(
    "Reply with exactly: Setup complete — Claude Sonnet 4.6 is ready for code generation.",
    session=setup_session,
)
print(response.text)
# Out:
# <frozen abc>:106: ExperimentalWarning: [HARNESS] MemoryStore is experimental and may change or be removed in future versions without notice.
# <frozen abc>:106: ExperimentalWarning: [SKILLS] SkillResource is experimental and may change or be removed in future versions without notice.
# Setup complete — Claude Sonnet 4.6 is ready for code generation.

# %% [markdown]
# ## 🏗️ Code Generation — From Specification to Implementation
#
# Think of Claude as a **senior developer doing pair programming** with you. Like any strong pair partner, it needs context: what are you building, what are the constraints, and what quality bar matters here?
#
# A vague prompt is like saying, *"build me something nice"* and walking away. A detailed specification is more like handing your teammate a ticket with acceptance criteria, edge cases, and architecture notes. **Vague specs get generic code; detailed specs get production-ready code.**

# %%
code_generation_session = agent.create_session()

trade_spec_prompt = """
Write a Python function called `calculate_trade_settlement` that:
- takes a trade dictionary with keys: symbol, quantity, price, trade_date, settlement_type
- calculates the settlement date based on T+1 for stocks and T+2 for bonds
- computes total value including a 0.1% commission fee
- returns a settlement dictionary with all computed fields
- includes type hints and a docstring
- handles edge cases like missing fields, invalid values, unsupported settlement types, and malformed dates

Use modern Python best practices and return only the code in a single fenced Python code block.
"""

response = await agent.run(trade_spec_prompt, session=code_generation_session)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[2], line 15
#      11
#      12 Use modern Python best practices and return only the code in a single fenced Python code block.
#      13 """
#      14
# ---> 15 response = await agent.run(trade_spec_prompt, session=code_generation_session)
#      16 print(response.text)
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_agents.py:954, in RawAgent.run.<locals>._run_non_streaming()
#     952 async def _run_non_streaming() -> AgentResponse[Any]:
#     953     ctx = await _prepare_run_context()
# --> 954     response = await self._call_chat_client(ctx, stream=False)
#     955     return await self._parse_non_streaming_response(ctx, response)
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_tools.py:2408, in FunctionInvocationLayer.get_response.<locals>._get_response()
#    2403 errors_in_a_row = approval_result.get("errors_in_a_row", errors_in_a_row)
#    2404 total_function_calls += approval_result.get("function_call_count", 0)
#    2406 response = cast(
#    2407     ChatResponse[Any],
# -> 2408     await super_get_response(
#    2409         messages=prepped_messages,
#    2410         stream=False,
#    2411         options=mutable_options,
#    2412         compaction_strategy=compaction_strategy,
#    2413         tokenizer=tokenizer,
#    2414         client_kwargs=filtered_kwargs,
#    2415     ),
#    2416 )
#    2417 aggregated_usage = add_usage_details(aggregated_usage, response.usage_details)
#    2418 _update_continuation_state(
#    2419     filtered_kwargs,
#    2420     response,
#    2421     session=invocation_session,
#    2422     options=mutable_options,
#    2423 )
#
# File ~/.local/lib/python3.12/site-packages/agent_framework_anthropic/_chat_client.py:551, in RawAnthropicClient._inner_get_response.<locals>._get_response()
#     550 async def _get_response() -> ChatResponse:
# --> 551     message = await self.anthropic_client.beta.messages.create(**run_options, stream=False)  # type: ignore[misc]
#     552     return self._process_message(message, options)
#
# File ~/.local/lib/python3.12/site-packages/anthropic/resources/beta/messages/messages.py:2853, in AsyncMessages.create(self, max_tokens, messages, model, container, context_management, inference_geo, mcp_servers, metadata, output_config, output_format, service_tier, speed, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, betas, extra_headers, extra_query, extra_body, timeout)
#    2847 merged_output_config = _merge_output_configs(output_config, output_format)
#    2849 extra_headers = {
#    2850     **strip_not_given({"anthropic-beta": ",".join(str(e) for e in betas) if is_given(betas) else not_given}),
#    2851     **(extra_headers or {}),
#    2852 }
# -> 2853 return await self._post(
#    2854     "/v1/messages?beta=true",
#    2855     body=await async_maybe_transform(
#    2856         {
#    2857             "max_tokens": max_tokens,
#    2858             "messages": messages,
#    2859             "model": model,
#    2860             "container": container,
#    2861             "context_management": context_management,
#    2862             "inference_geo": inference_geo,
#    2863             "mcp_servers": mcp_servers,
#    2864             "metadata": metadata,
#    2865             "output_config": merged_output_config,
#    2866             "output_format": omit,
#    2867             "service_tier": service_tier,
#    2868             "speed": speed,
#    2869             "stop_sequences": stop_sequences,
#    2870             "stream": stream,
#    2871             "system": system,
#    2872             "temperature": temperature,
#    2873             "thinking": thinking,
#    2874             "tool_choice": tool_choice,
#    2875             "tools": tools,
#    2876             "top_k": top_k,
#    2877             "top_p": top_p,
#    2878         },
#    2879         message_create_params.MessageCreateParamsStreaming
#    2880         if stream
#    2881         else message_create_params.MessageCreateParamsNonStreaming,
#    2882     ),
#    2883     options=make_request_options(
#    2884         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2885     ),
#    2886     cast_to=BetaMessage,
#    2887     stream=stream or False,
#    2888     stream_cls=AsyncStream[BetaRawMessageStreamEvent],
#    2889 )
#
# File ~/.local/lib/python3.12/site-packages/anthropic/_base_client.py:1992, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1983     warnings.warn(
#    1984         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1985         "Please pass raw bytes via the `content` parameter instead.",
#    1986         DeprecationWarning,
#    1987         stacklevel=2,
#    1988     )
#    1989 opts = FinalRequestOptions.construct(
#    1990     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1991 )
# -> 1992 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.12/site-packages/anthropic/_base_client.py:1777, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1774             await err.response.aread()
#    1776         log.debug("Re-raising status error")
# -> 1777         raise self._make_status_error_from_response(err.response) from None
#    1779     break
#    1781 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}, 'request_id': 'req_011CayEMfan8u2s6zQKdEUxs'}

# %% [markdown]
# ## 🔍 Code Review — Finding Bugs Before They Find You
#
# One of Claude's most useful enterprise skills is code review. It can scan for bugs, security vulnerabilities, and performance issues with the consistency of a reviewer who never gets tired, never loses context, and somehow remembers every painful postmortem.
#
# It's a bit like having a security engineer, a senior reviewer, and a QA lead all leaning over the same pull request — minus the scheduling meeting.

# %%
review_session = agent.create_session()

buggy_code = '''
def process_payment(amount, currency, account_id):
    # Convert to base currency
    rates = {"USD": 1.0, "EUR": 0.85, "GBP": 0.73}
    converted = amount * rates[currency]
    
    # Apply discount for large transactions
    if amount > 10000:
        discount = amount * 0.02
        converted = converted - discount
    
    # Format for database
    result = {
        "amount": round(converted, 2),
        "account": account_id,
        "timestamp": str(datetime.now()),
        "status": "completed"
    }
    
    # Log transaction
    log_file = open(f"/tmp/transactions_{account_id}.log", "a")
    log_file.write(str(result))
    
    return result
'''

review_prompt = f"""
Review the following Python function as if it were part of a payment pipeline at a financial services company.

For your review:
1. Identify correctness bugs, security issues, resource management problems, and missing validation.
2. Explain why each issue matters in production.
3. Suggest concrete fixes.
4. Provide a corrected version of the function.

Code to review:
{buggy_code}
"""

response = await agent.run(review_prompt, session=review_session)
print(response.text)
# Out:
# # Payment Pipeline Code Review
#
# ## Executive Summary
#
# This function has **critical issues** that would be unacceptable in any production financial system. The problems span correctness, security, resource management, and validation — any one of which could cause financial loss, data corruption, or regulatory violations.
#
# ---
#
# ## Issue Breakdown
#
# ### 🔴 Critical: Floating-Point Arithmetic for Currency
#
# ```python
# # BUGGY
# converted = amount * rates[currency]  # Floating-point imprecision
# result = {"amount": round(converted, 2), ...}
# ```
#
# **Why it matters:** IEEE 754 floating-point cannot represent most decimal fractions exactly. In a payment pipeline, this causes silent rounding errors that compound across millions of transactions, leading to financial discrepancies and failed audits.
#
# ```python
# >>> 0.1 + 0.2
# 0.30000000000000004
# >>> 1234.56 * 0.85
# 1049.376  # May not round as expected at scale
# ```
#
# **Fix:** Use Python's `decimal.Decimal` with explicit precision and rounding mode.
#
# ```python
# from decimal import Decimal, ROUND_HALF_UP, InvalidOperation
#
# rates = {"USD": Decimal("1.0"), "EUR": Decimal("0.85"), "GBP": Decimal("0.73")}
# amount = Decimal(str(amount))  # Convert input safely
# converted = (amount * rates[currency]).quantize(Decimal("0.01"), rounding=ROUND_HALF_UP)
# ```
#
# ---
#
# ### 🔴 Critical: No Input Validation
#
# ```python
# # BUGGY — no validation whatsoever
# def process_payment(amount, currency, account_id):
#     rates = {"USD": 1.0, "EUR": 0.85, "GBP": 0.73}
#     converted = amount * rates[currency]  # KeyError if currency unknown
# ```
#
# **Why it matters:**
# - A negative `amount` would process a negative payment (accidental credit/refund)
# - An unknown `currency` raises an unhandled `KeyError`, crashing the pipeline
# - A `None` or string `amount` raises a `TypeError`
# - An empty/None `account_id` writes to an unintended log file and corrupts the DB record
#
# **Fix:** Validate all inputs explicitly before any processing.
#
# ```python
# SUPPORTED_CURRENCIES = frozenset({"USD", "EUR", "GBP"})
#
# if not isinstance(amount, (int, float, Decimal)):
#     raise TypeError(f"amount must be numeric, got {type(amount).__name__}")
# if amount <= 0:
#     raise ValueError(f"amount must be positive, got {amount}")
# if currency not in SUPPORTED_CURRENCIES:
#     raise ValueError(f"Unsupported currency: {currency!r}")
# if not account_id or not isinstance(account_id, str):
#     raise ValueError("account_id must be a non-empty string")
# ```
#
# ---
#
# ### 🔴 Critical: Path Traversal / Log Injection Security Vulnerability
#
# ```python
# # BUGGY
# log_file = open(f"/tmp/transactions_{account_id}.log", "a")
# log_file.write(str(result))
# ```
#
# **Why it matters:**
# 1. **Path traversal:** If `account_id = "../../etc/cron.d/evil"`, the log writes to an arbitrary system path. An attacker could overwrite sensitive files.
# 2. **Log injection:** `str(result)` writes a raw dict with no sanitization. A crafted `account_id` containing newlines could inject fake log entries, corrupting audit trails.
# 3. **`/tmp` is inappropriate** for financial audit logs — it's world-readable on many systems and cleared on reboot.
#
# ```python
# # Attacker input example:
# account_id = "../../../etc/passwd"
# # Results in: open("/tmp/transactions/../../../etc/passwd.log", "a")
# ```
#
# **Fix:**
# ```python
# import re
# import logging
#
# # Whitelist account_id format
# if not re.fullmatch(r"[A-Za-z0-9_-]{1,64}", account_id):
#     raise ValueError(f"Invalid account_id format: {account_id!r}")
#
# # Use structured logging, not raw file I/O
# logger = logging.getLogger("payment_pipeline")
# logger.info("Transaction processed", extra={"transaction": result})
# ```
#
# ---
#
# ### 🔴 Critical: File Handle Never Closed (Resource Leak)
#
# ```python
# # BUGGY
# log_file = open(f"/tmp/transactions_{account_id}.log", "a")
# log_file.write(str(result))
# # log_file.close() is NEVER called
# ```
#
# **Why it matters:** In a high-throughput payment pipeline, this leaks a file descriptor on every call. Linux defaults to 1024 open file descriptors per process. Under load, this causes `OSError: [Errno 24] Too many open files`, crashing the entire payment service. Data may also not be flushed to disk.
#
# **Fix:** Always use a context manager.
#
# ```python
# with open(log_path, "a") as log_file:
#     log_file.write(json.dumps(result) + "\n")
# ```
#
# ---
#
# ### 🟠 High: Discount Applied to Wrong Value (Logic Bug)
#
# ```python
# # BUGGY
# if amount > 10000:
#     discount = amount * 0.02      # Discount calculated on original amount
#     converted = converted - discount  # Subtracted from converted amount (different currency!)
# ```
#
# **Why it matters:** The discount is calculated in the *original currency* but subtracted from the *converted (base currency) value*. For a €15,000 payment, the discount is `15000 * 0.02 = 300 EUR` but is subtracted from the USD-converted value, producing a mathematically incorrect result. This is a financial calculation error.
#
# **Fix:** Apply the discount consistently, before or after conversion, not mixed:
#
# ```python
# # Apply discount to original amount first, then convert
# if amount > Decimal("10000"):
#     discount_rate = Decimal("0.02")
#     amount = amount * (1 - discount_rate)
#
# converted = (amount * rates[currency]).quantize(Decimal("0.01"), rounding=ROUND_HALF_UP)
# ```
#
# ---
#
# ### 🟠 High: Non-Deterministic, Non-UTC Timestamp
#
# ```python
# # BUGGY
# "timestamp": str(datetime.now())
# ```
#
# **Why it matters:**
# - `datetime.now()` returns **local server time** with no timezone info. If servers are in different regions or DST changes occur, timestamps become ambiguous and non-comparable — a serious problem for financial audit trails and dispute resolution.
# - `str(datetime.now())` produces `2024-01-15 10:23:45.123456` — not ISO 8601 compliant, making parsing fragile.
#
# **Fix:**
# ```python
# from datetime import datetime, timezone
#
# "timestamp": datetime.now(timezone.utc).isoformat()
# # Produces: "2024-01-15T10:23:45.123456+00:00"
# ```
#
# ---
#
# ### 🟡 Medium: No Transaction ID / Idempotency Key
#
# ```python
# result = {
#     "amount": round(converted, 2),
#     "account": account_id,
#     "timestamp": str(datetime.now()),
#     "status": "completed"
# }
# ```
#
# **Why it matters:** Without a unique transaction ID, there is no way to:
# - Detect duplicate submissions (network retries causing double charges)
# - Correlate logs to database records
# - Support idempotent retries
#
# **Fix:**
# ```python
# import uuid
# "transaction_id": str(uuid.uuid4())
# ```
#
# ---
#
# ### 🟡 Medium: Hardcoded Exchange Rates
#
# ```python
# rates = {"USD": 1.0, "EUR": 0.85, "GBP": 0.73}
# ```
#
# **Why it matters:** Exchange rates change continuously. Hardcoded rates will silently produce incorrect conversions as markets move, causing financial loss and potential regulatory violations (MiFID II, etc.).
#
# **Fix:** Inject rates as a parameter or fetch from a rate service, with a cache TTL.
#
# ```python
# def process_payment(amount, currency, account_id, exchange_rates: dict[str, Decimal]):
#     ...
# ```
#
# ---
#
# ### 🟡 Medium: Status Hardcoded as "completed"
#
# ```python
# "status": "completed"
# ```
#
# **Why it matters:** The function hasn't actually submitted anything to a payment processor or database. Marking a transaction "completed" before it's persisted means a crash between `return result` and the caller saving it would produce a "completed" transaction that never actually executed.
#
# **Fix:** Status should be set by the system that confirms persistence/processing, not this function. Return `"pending"` and update to `"completed"` only after confirmed DB write.
#
# ---
#
# ## Corrected Implementation
#
# ```python
# """
# Payment processing module for financial transaction pipeline.
#
# Handles currency conversion, discount application, and transaction
# record creation with full input validation and audit logging.
# """
#
# import json
# import logging
# import re
# import uuid
# from decimal import Decimal, ROUND_HALF_UP, InvalidOperation
# from datetime import datetime, timezone
# from typing import Any
#
# logger = logging.getLogger(__name__)
#
# # Supported currencies — extend via configuration, not code changes
# SUPPORTED_CURRENCIES: frozenset[str] = frozenset({"USD", "EUR", "GBP"})
#
# # Account ID whitelist pattern — alphanumeric, hyphens, underscores, max 64 chars
# _ACCOUNT_ID_PATTERN = re.compile(r"^[A-Za-z0-9_-]{1,64}$")
#
# # Discount threshold and rate as constants
# LARGE_TRANSACTION_THRESHOLD = Decimal("10000.00")
# LARGE_TRANSACTION_DISCOUNT_RATE = Decimal("0.02")
#
#
# class PaymentValidationError(ValueError):
#     """Raised when payment input fails validation."""
#
#
# class UnsupportedCurrencyError(PaymentValidationError):
#     """Raised when an unsupported currency code is provided."""
#
#
# def _validate_inputs(
#     amount: Decimal,
#     currency: str,
#     account_id: str,
#     exchange_rates: dict[str, Decimal],
# ) -> None:
#     """
#     Validate all inputs before any financial processing occurs.
#
#     Args:
#         amount: Payment amount, must be positive.
#         currency: ISO 4217 currency code.
#         account_id: Validated account identifier.
#         exchange_rates: Mapping of currency codes to conversion rates.
#
#     Raises:
#         PaymentValidationError: On any invalid input.
#         UnsupportedCurrencyError: If currency is not supported.
#     """
#     if not isinstance(amount, Decimal):
#         raise PaymentValidationError(
#             f"amount must be Decimal, got {type(amount).__name__}"
#         )
#     if amount <= Decimal("0"):
#         raise PaymentValidationError(
#             f"amount must be positive, got {amount}"
#         )
#     # Guard against unreasonably large amounts (adjust limit per business rules)
#     if amount > Decimal("1_000_000_000"):
#         raise PaymentValidationError(
#             f"amount exceeds maximum allowed value: {amount}"
#         )
#
#     if not isinstance(currency, str):
#         raise PaymentValidationError(
#             f"currency must be a string, got {type(currency).__name__}"
#         )
#     if currency not in SUPPORTED_CURRENCIES:
#         raise UnsupportedCurrencyError(
#             f"Unsupported currency: {currency!r}. "
#             f"Supported: {sorted(SUPPORTED_CURRENCIES)}"
#         )
#     if currency not in exchange_rates:
#         raise PaymentValidationError(
#             f"No exchange rate provided for currency: {currency!r}"
#         )
#
#     if not isinstance(account_id, str) or not account_id:
#         raise PaymentValidationError("account_id must be a non-empty string")
#     if not _ACCOUNT_ID_PATTERN.fullmatch(account_id):
#         raise PaymentValidationError(
#             f"account_id contains invalid characters or exceeds length limit: "
#             f"{account_id!r}"
#         )
#
#
# def _apply_discount(amount: Decimal) -> tuple[Decimal, Decimal]:
#     """
#     Apply large-transaction discount if applicable.
#
#     Args:
#         amount: Original payment amount in source currency.
#
#     Returns:
#         Tuple of (discounted_amount, discount_applied).
#     """
#     if amount > LARGE_TRANSACTION_THRESHOLD:
#         discount = (amount * LARGE_TRANSACTION_DISCOUNT_RATE).quantize(
#             Decimal("0.01"), rounding=ROUND_HALF_UP
#         )
#         return amount - discount, discount
#     return amount, Decimal("0.00")
#
#
# def process_payment(
#     amount: Decimal,
#     currency: str,
#     account_id: str,
#     exchange_rates: dict[str, Decimal],
# ) -> dict[str, Any]:
#     """
#     Validate and prepare a payment transaction record.
#
#     Converts the payment amount to USD base currency, applies any applicable
#     discounts, and returns a structured transaction record ready for
#     persistence. Does NOT persist or submit the transaction — status is
#     set to 'pending' until confirmed by the calling layer.
#
#     Args:
#         amount: Payment amount as Decimal in the specified currency.
#         currency: ISO 4217 currency code (e.g., "USD", "EUR", "GBP").
#         account_id: Validated account identifier (alphanumeric/hyphens/underscores).
#         exchange_rates: Current exchange rates mapping currency -> Decimal rate.
#                         Must be injected by caller (no hardcoded rates).
#
#     Returns:
#         Dictionary containing the transaction record with fields:
#             - transaction_id: UUID4 unique identifier
#             - amount_original: Original amount in source currency
#             - amount_converted: Converted amount in base currency (USD)
#             - currency: Source currency code
#             - discount_applied: Discount amount in source currency
#             - account_id: Sanitized account identifier
#             - timestamp: ISO 8601 UTC timestamp
#             - status: Always "pending" — caller must update after persistence
#
#     Raises:
#         PaymentValidationError: If any input fails validation.
#         UnsupportedCurrencyError: If currency is not in supported set.
#         InvalidOperation: If Decimal arithmetic fails unexpectedly.
#     """
#     _validate_inputs(amount, currency, account_id, exchange_rates)
#
#     # Apply discount in source currency before conversion (consistent arithmetic)
#     discounted_amount, discount_applied = _apply_discount(amount)
#
#     # Convert to base currency using injected rates
#     rate = exchange_rates[currency]
#     converted = (discounted_amount * rate).quantize(
#         Decimal("0.01"), rounding=ROUND_HALF_UP
#     )
#
#     transaction_id = str(uuid.uuid4())
#     timestamp = datetime.now(timezone.utc).isoformat()
#
#     result: dict[str, Any] = {
#         "transaction_id": transaction_id,
#         "amount_original": str(amount),           # Serialize Decimal as string
#         "amount_converted": str(converted),        # to avoid JSON precision loss
#         "currency": currency,
#         "discount_applied": str(discount_applied),
#         "account_id": account_id,
#         "timestamp": timestamp,
#         "status": "pending",                       # Caller sets "completed" after DB write
#     }
#
#     # Structured audit log — use logging framework, not raw file I/O
#     logger.info(
#         "Payment record created",
#         extra={
#             "transaction_id": transaction_id,
#             "account_id": account_id,
#             "currency": currency,
#             "amount_original": str(amount),
#             "amount_converted": str(converted),
#             "timestamp": timestamp,
#         },
#     )
#
#     return result
# ```
#
# ---
#
# ## Summary Table
#
# | # | Severity | Issue | Impact |
# |---|----------|-------|--------|
# | 1 | 🔴 Critical | Floating-point currency arithmetic | Silent financial rounding errors |
# | 2 | 🔴 Critical | No input validation | Crashes, negative payments, injection |
# | 3 | 🔴 Critical | Path traversal via `account_id` | Arbitrary file write, audit corruption |
# | 4 | 🔴 Critical | File handle never closed | Service crash under load |
# | 5 | 🟠 High | Discount applied across currency boundary | Incorrect financial calculations |
# | 6 | 🟠 High | Non-UTC, non-ISO timestamp | Ambiguous audit trail, dispute failures |
# | 7 | 🟡 Medium | No transaction ID | Duplicate charges, no traceability |
# | 8 | 🟡 Medium | Hardcoded exchange rates

# %% [markdown]
# ## 🔄 Language Translation — Modernizing Legacy Code
#
# LegacyBridge's oldest business rules still live in legacy systems. Some logic is buried in COBOL, some in older Java services, and much of it encodes decisions the business depends on every day.
#
# Translating that code is not just syntax conversion — it's more like using a **Rosetta Stone for software**. You want to preserve the intent, the edge cases, and the institutional knowledge, while expressing it in a modern language your current team can safely evolve.

# %%
translation_session = agent.create_session()

legacy_java_code = """
// Legacy Java function
public class TradeValidator {
    public static ValidationResult validateTrade(Trade trade) {
        ValidationResult result = new ValidationResult();
        
        if (trade.getQuantity() <= 0) {
            result.addError(\"Invalid quantity\");
            return result;
        }
        
        if (trade.getPrice() < 0.01) {
            result.addError(\"Price below minimum tick\");
            return result;
        }
        
        double notional = trade.getQuantity() * trade.getPrice();
        if (notional > trade.getAccount().getRiskLimit()) {
            result.addError(\"Exceeds risk limit: \" + notional);
            return result;
        }
        
        if (isMarketClosed(trade.getExchange())) {
            result.addError(\"Market is closed\");
            return result;
        }
        
        result.setValid(true);
        result.setNotional(notional);
        return result;
    }
}
"""

translation_prompt = f"""
Translate the following legacy Java trading validation logic into modern Python.

Requirements:
- use dataclasses
- use type hints
- use Pythonic patterns
- preserve the business logic exactly
- include a short explanation of the main translation choices after the code

Java code:
{legacy_java_code}
"""

response = await agent.run(translation_prompt, session=translation_session)
print(response.text)
# Out:
# # Python Translation of Java Trade Validator
#
# ## Python Code
#
# ```python
# """
# Trade validation module.
#
# Translates legacy Java TradeValidator business logic into modern Python
# using dataclasses, type hints, and Pythonic patterns.
# """
#
# from __future__ import annotations
#
# from dataclasses import dataclass, field
# from typing import Optional
#
#
# # ---------------------------------------------------------------------------
# # Domain models
# # ---------------------------------------------------------------------------
#
# @dataclass
# class Account:
#     """Represents a trading account with an associated risk limit."""
#
#     account_id: str
#     risk_limit: float
#
#
# @dataclass
# class Trade:
#     """Represents a single trade order."""
#
#     quantity: int
#     price: float
#     exchange: str
#     account: Account
#
#
# @dataclass
# class ValidationResult:
#     """
#     Holds the outcome of a trade validation attempt.
#
#     Attributes:
#         is_valid:  True only when all validation checks pass.
#         notional:  Computed notional value (quantity × price); set on success.
#         errors:    Accumulated list of human-readable error messages.
#     """
#
#     is_valid: bool = False
#     notional: Optional[float] = None
#     errors: list[str] = field(default_factory=list)
#
#     def add_error(self, message: str) -> None:
#         """Append an error message to the errors list."""
#         self.errors.append(message)
#
#     @property
#     def has_errors(self) -> bool:
#         """Return True if any errors have been recorded."""
#         return bool(self.errors)
#
#
# # ---------------------------------------------------------------------------
# # Market-hours helper (mirrors Java isMarketClosed)
# # ---------------------------------------------------------------------------
#
# _CLOSED_EXCHANGES: frozenset[str] = frozenset({"CLOSED_EXCHANGE"})
#
#
# def is_market_closed(exchange: str) -> bool:
#     """
#     Return True when the given exchange is not currently accepting orders.
#
#     Args:
#         exchange: Exchange identifier string (e.g. "NYSE", "LSE").
#
#     Returns:
#         True if the market is closed, False otherwise.
#     """
#     return exchange in _CLOSED_EXCHANGES
#
#
# # ---------------------------------------------------------------------------
# # Validation constants
# # ---------------------------------------------------------------------------
#
# MIN_PRICE_TICK: float = 0.01
#
#
# # ---------------------------------------------------------------------------
# # Core validator
# # ---------------------------------------------------------------------------
#
# def validate_trade(trade: Trade) -> ValidationResult:
#     """
#     Validate a trade against quantity, price, risk-limit, and market-hours rules.
#
#     Mirrors the early-return guard-clause pattern of the original Java method:
#     each failing check records an error and returns immediately, so at most
#     one error is ever present in the result (matching the Java behaviour).
#
#     Args:
#         trade: The trade to validate.
#
#     Returns:
#         A :class:`ValidationResult` that is either marked valid with a
#         computed notional, or invalid with a single descriptive error.
#
#     Examples:
#         >>> account = Account(account_id="ACC-1", risk_limit=100_000.0)
#         >>> trade = Trade(quantity=100, price=50.0, exchange="NYSE", account=account)
#         >>> result = validate_trade(trade)
#         >>> result.is_valid
#         True
#         >>> result.notional
#         5000.0
#     """
#     result = ValidationResult()
#
#     # Guard 1 – quantity must be positive
#     if trade.quantity <= 0:
#         result.add_error("Invalid quantity")
#         return result
#
#     # Guard 2 – price must meet the minimum tick size
#     if trade.price < MIN_PRICE_TICK:
#         result.add_error("Price below minimum tick")
#         return result
#
#     # Guard 3 – notional must not exceed the account risk limit
#     notional: float = trade.quantity * trade.price
#     if notional > trade.account.risk_limit:
#         result.add_error(f"Exceeds risk limit: {notional}")
#         return result
#
#     # Guard 4 – the exchange must be open
#     if is_market_closed(trade.exchange):
#         result.add_error("Market is closed")
#         return result
#
#     # All checks passed
#     result.is_valid = True
#     result.notional = notional
#     return result
# ```
#
# ---
#
# ## Tests
#
# ```python
# """Unit tests for the trade validator."""
#
# import pytest
# from trade_validator import (
#     Account,
#     Trade,
#     ValidationResult,
#     validate_trade,
#     MIN_PRICE_TICK,
# )
#
#
# # ---------------------------------------------------------------------------
# # Fixtures
# # ---------------------------------------------------------------------------
#
# @pytest.fixture()
# def account() -> Account:
#     return Account(account_id="ACC-001", risk_limit=100_000.0)
#
#
# @pytest.fixture()
# def valid_trade(account: Account) -> Trade:
#     return Trade(quantity=100, price=50.0, exchange="NYSE", account=account)
#
#
# # ---------------------------------------------------------------------------
# # Happy path
# # ---------------------------------------------------------------------------
#
# def test_valid_trade_is_accepted(valid_trade: Trade) -> None:
#     result = validate_trade(valid_trade)
#
#     assert result.is_valid is True
#     assert result.notional == pytest.approx(5_000.0)
#     assert not result.has_errors
#
#
# # ---------------------------------------------------------------------------
# # Guard 1 – quantity
# # ---------------------------------------------------------------------------
#
# @pytest.mark.parametrize("quantity", [0, -1, -100])
# def test_invalid_quantity_rejected(quantity: int, account: Account) -> None:
#     trade = Trade(quantity=quantity, price=50.0, exchange="NYSE", account=account)
#     result = validate_trade(trade)
#
#     assert result.is_valid is False
#     assert "Invalid quantity" in result.errors
#     assert len(result.errors) == 1          # early-return: only one error
#
#
# # ---------------------------------------------------------------------------
# # Guard 2 – price
# # ---------------------------------------------------------------------------
#
# @pytest.mark.parametrize("price", [0.0, 0.009, -1.0])
# def test_price_below_minimum_tick_rejected(price: float, account: Account) -> None:
#     trade = Trade(quantity=10, price=price, exchange="NYSE", account=account)
#     result = validate_trade(trade)
#
#     assert result.is_valid is False
#     assert "Price below minimum tick" in result.errors
#     assert len(result.errors) == 1
#
#
# def test_price_exactly_at_minimum_tick_accepted(account: Account) -> None:
#     trade = Trade(quantity=1, price=MIN_PRICE_TICK, exchange="NYSE", account=account)
#     result = validate_trade(trade)
#
#     assert result.is_valid is True
#
#
# # ---------------------------------------------------------------------------
# # Guard 3 – risk limit
# # ---------------------------------------------------------------------------
#
# def test_notional_exceeding_risk_limit_rejected(account: Account) -> None:
#     # notional = 10_000 * 20.0 = 200_000 > risk_limit 100_000
#     trade = Trade(quantity=10_000, price=20.0, exchange="NYSE", account=account)
#     result = validate_trade(trade)
#
#     assert result.is_valid is False
#     assert any("Exceeds risk limit" in err for err in result.errors)
#     assert len(result.errors) == 1
#
#
# def test_notional_exactly_at_risk_limit_accepted(account: Account) -> None:
#     # notional = 2_000 * 50.0 = 100_000 == risk_limit
#     trade = Trade(quantity=2_000, price=50.0, exchange="NYSE", account=account)
#     result = validate_trade(trade)
#
#     assert result.is_valid is True
#     assert result.notional == pytest.approx(100_000.0)
#
#
# # ---------------------------------------------------------------------------
# # Guard 4 – market hours
# # ---------------------------------------------------------------------------
#
# def test_closed_market_rejected(account: Account) -> None:
#     trade = Trade(quantity=100, price=50.0, exchange="CLOSED_EXCHANGE", account=account)
#     result = validate_trade(trade)
#
#     assert result.is_valid is False
#     assert "Market is closed" in result.errors
#     assert len(result.errors) == 1
#
#
# def test_open_market_accepted(account: Account) -> None:
#     trade = Trade(quantity=100, price=50.0, exchange="LSE", account=account)
#     result = validate_trade(trade)
#
#     assert result.is_valid is True
#
#
# # ---------------------------------------------------------------------------
# # ValidationResult helpers
# # ---------------------------------------------------------------------------
#
# def test_has_errors_false_when_no_errors() -> None:
#     result = ValidationResult()
#     assert result.has_errors is False
#
#
# def test_has_errors_true_after_add_error() -> None:
#     result = ValidationResult()
#     result.add_error("something went wrong")
#     assert result.has_errors is True
# ```
#
# ---
#
# ## Translation Choices
#
# | Concern | Java approach | Python approach | Rationale |
# |---|---|---|---|
# | **Data containers** | Plain classes with getters/setters | `@dataclass` | Eliminates boilerplate; `__init__`, `__repr__`, and `__eq__` are generated automatically |
# | **Naming convention** | `camelCase` (`getQuantity`, `isValid`) | `snake_case` (`quantity`, `is_valid`) | Follows PEP 8 and Python community norms |
# | **Static method** | `public static ValidationResult validateTrade(Trade trade)` | Module-level function `validate_trade(trade: Trade)` | Python favours free functions over static methods when no class state is involved |
# | **Mutable default** | `new ArrayList<>()` in constructor | `field(default_factory=list)` | Avoids the classic Python shared-mutable-default pitfall |
# | **Boolean property** | `result.setValid(true)` | `result.is_valid = True` | Direct attribute assignment is idiomatic; a `@property` is added only where computed logic is needed (`has_errors`) |
# | **String formatting** | `"Exceeds risk limit: " + notional` | f-string `f"Exceeds risk limit: {notional}"` | f-strings are the modern, readable Python standard |
# | **Guard-clause pattern** | Preserved exactly | Preserved exactly | The early-return structure is intentional business logic (one error per call); it maps naturally to Python |
# | **Constants** | Magic literals inline | `MIN_PRICE_TICK`, `_CLOSED_EXCHANGES` | Named constants improve readability and make future changes to tick size or exchange lists a single-point edit |
# | **Type hints** | Enforced by compiler | `from __future__ import annotations` + hints throughout | Brings Java's compile-time safety closer to Python via static analysis tools (mypy, pyright) |

# %% [markdown]
# ## 🧪 Test Generation — Building a Safety Net
#
# Before you modernize aggressively, you need tests. Think of tests as the **measuring tape before cutting fabric** — they capture expected behavior so you can refactor with confidence instead of crossed fingers.
#
# For legacy modernization, test generation is often the bridge between *"we're scared to touch it"* and *"we can improve this safely."*

# %%
test_generation_prompt = """
Generate pytest tests for the Python trade validator you just created.

Please include:
- happy path tests
- edge cases
- boundary conditions
- error cases

Return the tests in a single fenced Python code block and briefly note what each test category is protecting against.
"""

response = await agent.run(test_generation_prompt, session=translation_session)
print(response.text)
# Out:
# ```python
# """
# Pytest test suite for the trade validator module.
#
# Coverage map
# ------------
# Category                        | What it protects against
# --------------------------------|----------------------------------------------------------
# Happy path                      | Regression on the core success flow
# Quantity boundaries             | Off-by-one errors around the zero/positive boundary
# Price boundaries                | Floating-point edge cases around MIN_PRICE_TICK (0.01)
# Risk-limit boundaries           | Exact-equality and just-over boundary for notional cap
# Market-hours                    | Closed/open exchange routing
# Result dataclass behaviour      | Mutation of shared state via default_factory; property logic
# Notional arithmetic             | Floating-point precision in quantity × price calculation
# Combined/integration            | Correct guard ordering (only one error returned per call)
# """
#
# from __future__ import annotations
#
# import math
# import sys
# from dataclasses import fields
#
# import pytest
#
# from trade_validator import (
#     MIN_PRICE_TICK,
#     Account,
#     Trade,
#     ValidationResult,
#     is_market_closed,
#     validate_trade,
# )
#
#
# # ---------------------------------------------------------------------------
# # Shared fixtures
# # ---------------------------------------------------------------------------
#
#
# @pytest.fixture()
# def standard_account() -> Account:
#     """A reusable account with a round risk limit."""
#     return Account(account_id="ACC-001", risk_limit=100_000.0)
#
#
# @pytest.fixture()
# def valid_trade(standard_account: Account) -> Trade:
#     """A trade that should pass every validation guard."""
#     return Trade(
#         quantity=100,
#         price=50.0,
#         exchange="NYSE",
#         account=standard_account,
#     )
#
#
# # ===========================================================================
# # 1. HAPPY PATH
# # Protects against: regressions that break the core success flow, ensures
# # is_valid is True and notional is correctly populated on a clean trade.
# # ===========================================================================
#
#
# class TestHappyPath:
#     def test_valid_trade_is_accepted(self, valid_trade: Trade) -> None:
#         result = validate_trade(valid_trade)
#
#         assert result.is_valid is True
#
#     def test_valid_trade_has_no_errors(self, valid_trade: Trade) -> None:
#         result = validate_trade(valid_trade)
#
#         assert result.errors == []
#         assert result.has_errors is False
#
#     def test_valid_trade_notional_is_populated(self, valid_trade: Trade) -> None:
#         result = validate_trade(valid_trade)
#
#         assert result.notional == pytest.approx(5_000.0)
#
#     def test_valid_trade_notional_equals_quantity_times_price(
#         self, valid_trade: Trade
#     ) -> None:
#         result = validate_trade(valid_trade)
#
#         expected = valid_trade.quantity * valid_trade.price
#         assert result.notional == pytest.approx(expected)
#
#
# # ===========================================================================
# # 2. QUANTITY BOUNDARY CONDITIONS
# # Protects against: off-by-one errors around the zero/positive boundary;
# # ensures the guard fires for non-positive values and passes for quantity=1.
# # ===========================================================================
#
#
# class TestQuantityBoundary:
#     @pytest.mark.parametrize(
#         "quantity",
#         [
#             0,           # exact boundary – must be rejected
#             -1,          # one below zero
#             -100,        # large negative
#             -sys.maxsize,  # extreme negative
#         ],
#     )
#     def test_non_positive_quantity_rejected(
#         self, quantity: int, standard_account: Account
#     ) -> None:
#         trade = Trade(
#             quantity=quantity,
#             price=50.0,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is False
#         assert "Invalid quantity" in result.errors
#
#     def test_quantity_of_one_accepted(self, standard_account: Account) -> None:
#         """Minimum valid quantity is 1 (strictly positive)."""
#         trade = Trade(
#             quantity=1,
#             price=0.01,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         # notional = 0.01 which is well within any reasonable risk limit
#         assert result.is_valid is True
#
#     def test_large_quantity_within_risk_limit_accepted(
#         self, standard_account: Account
#     ) -> None:
#         # 1 000 * 0.01 = 10.0 – tiny notional, large share count
#         trade = Trade(
#             quantity=1_000,
#             price=0.01,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#
#
# # ===========================================================================
# # 3. PRICE BOUNDARY CONDITIONS
# # Protects against: floating-point edge cases around MIN_PRICE_TICK (0.01);
# # ensures prices just below the tick are rejected and prices at/above pass.
# # ===========================================================================
#
#
# class TestPriceBoundary:
#     def test_price_exactly_at_minimum_tick_accepted(
#         self, standard_account: Account
#     ) -> None:
#         trade = Trade(
#             quantity=1,
#             price=MIN_PRICE_TICK,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#
#     def test_price_just_below_minimum_tick_rejected(
#         self, standard_account: Account
#     ) -> None:
#         just_below = MIN_PRICE_TICK - 1e-10
#         trade = Trade(
#             quantity=1,
#             price=just_below,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is False
#         assert "Price below minimum tick" in result.errors
#
#     @pytest.mark.parametrize(
#         "price",
#         [
#             0.0,
#             0.009,
#             0.0099999,
#             -0.01,
#             -1.0,
#             -sys.float_info.max,
#         ],
#     )
#     def test_prices_below_minimum_tick_rejected(
#         self, price: float, standard_account: Account
#     ) -> None:
#         trade = Trade(
#             quantity=1,
#             price=price,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is False
#         assert "Price below minimum tick" in result.errors
#
#     def test_price_just_above_minimum_tick_accepted(
#         self, standard_account: Account
#     ) -> None:
#         just_above = MIN_PRICE_TICK + 1e-10
#         trade = Trade(
#             quantity=1,
#             price=just_above,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#
#     def test_very_high_price_within_risk_limit_accepted(
#         self, standard_account: Account
#     ) -> None:
#         # 1 share at 99 999.99 – just under the 100 000 risk limit
#         trade = Trade(
#             quantity=1,
#             price=99_999.99,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#
#
# # ===========================================================================
# # 4. RISK-LIMIT BOUNDARY CONDITIONS
# # Protects against: fencepost errors on the notional cap; ensures trades
# # exactly at the limit pass and trades one epsilon over are rejected.
# # ===========================================================================
#
#
# class TestRiskLimitBoundary:
#     def test_notional_exactly_at_risk_limit_accepted(
#         self, standard_account: Account
#     ) -> None:
#         # 2 000 * 50.0 = 100 000.0 == risk_limit
#         trade = Trade(
#             quantity=2_000,
#             price=50.0,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#         assert result.notional == pytest.approx(100_000.0)
#
#     def test_notional_just_over_risk_limit_rejected(
#         self, standard_account: Account
#     ) -> None:
#         # Use a price that pushes notional fractionally above the limit
#         trade = Trade(
#             quantity=2_000,
#             price=50.0 + 1e-9,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is False
#         assert any("Exceeds risk limit" in err for err in result.errors)
#
#     def test_notional_well_over_risk_limit_rejected(
#         self, standard_account: Account
#     ) -> None:
#         trade = Trade(
#             quantity=10_000,
#             price=20.0,  # notional = 200 000
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is False
#
#     def test_error_message_contains_notional_value(
#         self, standard_account: Account
#     ) -> None:
#         trade = Trade(
#             quantity=10_000,
#             price=20.0,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert any("200000" in err for err in result.errors)
#
#     def test_zero_risk_limit_rejects_any_trade(self) -> None:
#         zero_limit_account = Account(account_id="ZERO", risk_limit=0.0)
#         trade = Trade(
#             quantity=1,
#             price=MIN_PRICE_TICK,
#             exchange="NYSE",
#             account=zero_limit_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is False
#         assert any("Exceeds risk limit" in err for err in result.errors)
#
#     def test_very_large_risk_limit_accepts_large_notional(self) -> None:
#         big_account = Account(account_id="BIG", risk_limit=sys.float_info.max)
#         trade = Trade(
#             quantity=1_000_000,
#             price=1_000.0,
#             exchange="NYSE",
#             account=big_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#
#
# # ===========================================================================
# # 5. MARKET-HOURS / EXCHANGE VALIDATION
# # Protects against: closed-market trades slipping through; ensures the
# # is_market_closed helper and the validator agree on exchange status.
# # ===========================================================================
#
#
# class TestMarketHours:
#     def test_closed_exchange_rejected(self, standard_account: Account) -> None:
#         trade = Trade(
#             quantity=100,
#             price=50.0,
#             exchange="CLOSED_EXCHANGE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is False
#         assert "Market is closed" in result.errors
#
#     @pytest.mark.parametrize("exchange", ["NYSE", "LSE", "NASDAQ", "TSX", "ASX"])
#     def test_open_exchanges_accepted(
#         self, exchange: str, standard_account: Account
#     ) -> None:
#         trade = Trade(
#             quantity=100,
#             price=50.0,
#             exchange=exchange,
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#
#     def test_is_market_closed_returns_true_for_closed_exchange(self) -> None:
#         assert is_market_closed("CLOSED_EXCHANGE") is True
#
#     def test_is_market_closed_returns_false_for_open_exchange(self) -> None:
#         assert is_market_closed("NYSE") is False
#
#     def test_is_market_closed_case_sensitive(self) -> None:
#         """Exchange identifiers are case-sensitive; lowercase should be open."""
#         assert is_market_closed("closed_exchange") is False
#
#     def test_empty_exchange_string_treated_as_open(
#         self, standard_account: Account
#     ) -> None:
#         """An empty string is not in the closed set – should not raise."""
#         trade = Trade(
#             quantity=1,
#             price=MIN_PRICE_TICK,
#             exchange="",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         # Business rule: unknown exchange ≠ closed exchange
#         assert result.is_valid is True
#
#
# # ===========================================================================
# # 6. VALIDATION RESULT DATACLASS BEHAVIOUR
# # Protects against: shared mutable default (list), property correctness,
# # and accidental mutation between independent ValidationResult instances.
# # ===========================================================================
#
#
# class TestValidationResultDataclass:
#     def test_default_is_invalid(self) -> None:
#         result = ValidationResult()
#
#         assert result.is_valid is False
#
#     def test_default_notional_is_none(self) -> None:
#         result = ValidationResult()
#
#         assert result.notional is None
#
#     def test_default_errors_is_empty_list(self) -> None:
#         result = ValidationResult()
#
#         assert result.errors == []
#
#     def test_errors_list_not_shared_between_instances(self) -> None:
#         """Regression guard for the classic mutable-default-argument bug."""
#         r1 = ValidationResult()
#         r2 = ValidationResult()
#         r1.add_error("only in r1")
#
#         assert r2.errors == []
#
#     def test_add_error_appends_message(self) -> None:
#         result = ValidationResult()
#         result.add_error("first error")
#         result.add_error("second error")
#
#         assert result.errors == ["first error", "second error"]
#
#     def test_has_errors_false_when_no_errors(self) -> None:
#         result = ValidationResult()
#
#         assert result.has_errors is False
#
#     def test_has_errors_true_after_add_error(self) -> None:
#         result = ValidationResult()
#         result.add_error("something went wrong")
#
#         assert result.has_errors is True
#
#     def test_has_errors_false_after_clearing_errors(self) -> None:
#         result = ValidationResult()
#         result.add_error("temporary")
#         result.errors.clear()
#
#         assert result.has_errors is False
#
#
# # ===========================================================================
# # 7. NOTIONAL ARITHMETIC PRECISION
# # Protects against: floating-point drift causing incorrect risk-limit
# # comparisons; uses pytest.approx for tolerance-aware assertions.
# # ===========================================================================
#
#
# class TestNotionalArithmetic:
#     def test_notional_is_quantity_times_price(self, standard_account: Account) -> None:
#         trade = Trade(
#             quantity=333,
#             price=3.33,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#         assert result.notional == pytest.approx(333 * 3.33)
#
#     def test_notional_with_fractional_price(self, standard_account: Account) -> None:
#         trade = Trade(
#             quantity=7,
#             price=0.07,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.is_valid is True
#         assert result.notional == pytest.approx(0.49, rel=1e-9)
#
#     def test_notional_not_set_on_failed_validation(
#         self, standard_account: Account
#     ) -> None:
#         """notional must remain None when validation fails before it is computed."""
#         trade = Trade(
#             quantity=0,  # fails guard 1 before notional is calculated
#             price=50.0,
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.notional is None
#
#     def test_notional_not_set_when_price_guard_fails(
#         self, standard_account: Account
#     ) -> None:
#         trade = Trade(
#             quantity=10,
#             price=0.0,  # fails guard 2
#             exchange="NYSE",
#             account=standard_account,
#         )
#         result = validate_trade(trade)
#
#         assert result.

# %% [markdown]
# ## 🔁 Iterative Refinement — The Conversation Advantage
#
# This is where sessions shine. Real development is rarely one-shot. It's more like shaping clay than stamping a coin: build the first version, inspect it, add guardrails, improve usability, then polish the design.
#
# With multi-turn chat, you can refine code naturally:
#
# - *Add error handling*
# - *Now make it async*
# - *Add logging*
# - *Expose metrics*
#
# Each turn inherits the earlier context, so the model improves the existing design instead of starting from scratch every time.

# %%
order_book_session = agent.create_session()

turn_1 = await agent.run(
    "Write a Python class for a simple order book that can add buy/sell orders and match them.",
    session=order_book_session,
)
print("=== Turn 1: Initial implementation ===\n")
print(turn_1.text)

turn_2 = await agent.run(
    "Good. Now add input validation and proper error handling.",
    session=order_book_session,
)
print("\n=== Turn 2: Added validation and error handling ===\n")
print(turn_2.text)

turn_3 = await agent.run(
    "Now add a method to get the current bid-ask spread and market depth.",
    session=order_book_session,
)
print("\n=== Turn 3: Added analytics methods ===\n")
print(turn_3.text)

turn_4 = await agent.run(
    "Finally, add type hints and a docstring for each method.",
    session=order_book_session,
)
print("\n=== Turn 4: Final refined version ===\n")
print(turn_4.text)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 order_book_session = agent.create_session()
#       2
# ----> 3 turn_1 = await agent.run(
#       4     "Write a Python class for a simple order book that can add buy/sell orders and match them.",
#       5     session=order_book_session,
#       6 )
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_agents.py:954, in RawAgent.run.<locals>._run_non_streaming()
#     952 async def _run_non_streaming() -> AgentResponse[Any]:
#     953     ctx = await _prepare_run_context()
# --> 954     response = await self._call_chat_client(ctx, stream=False)
#     955     return await self._parse_non_streaming_response(ctx, response)
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_tools.py:2408, in FunctionInvocationLayer.get_response.<locals>._get_response()
#    2403 errors_in_a_row = approval_result.get("errors_in_a_row", errors_in_a_row)
#    2404 total_function_calls += approval_result.get("function_call_count", 0)
#    2406 response = cast(
#    2407     ChatResponse[Any],
# -> 2408     await super_get_response(
#    2409         messages=prepped_messages,
#    2410         stream=False,
#    2411         options=mutable_options,
#    2412         compaction_strategy=compaction_strategy,
#    2413         tokenizer=tokenizer,
#    2414         client_kwargs=filtered_kwargs,
#    2415     ),
#    2416 )
#    2417 aggregated_usage = add_usage_details(aggregated_usage, response.usage_details)
#    2418 _update_continuation_state(
#    2419     filtered_kwargs,
#    2420     response,
#    2421     session=invocation_session,
#    2422     options=mutable_options,
#    2423 )
#
# File ~/.local/lib/python3.12/site-packages/agent_framework_anthropic/_chat_client.py:551, in RawAnthropicClient._inner_get_response.<locals>._get_response()
#     550 async def _get_response() -> ChatResponse:
# --> 551     message = await self.anthropic_client.beta.messages.create(**run_options, stream=False)  # type: ignore[misc]
#     552     return self._process_message(message, options)
#
# File ~/.local/lib/python3.12/site-packages/anthropic/resources/beta/messages/messages.py:2853, in AsyncMessages.create(self, max_tokens, messages, model, container, context_management, inference_geo, mcp_servers, metadata, output_config, output_format, service_tier, speed, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, betas, extra_headers, extra_query, extra_body, timeout)
#    2847 merged_output_config = _merge_output_configs(output_config, output_format)
#    2849 extra_headers = {
#    2850     **strip_not_given({"anthropic-beta": ",".join(str(e) for e in betas) if is_given(betas) else not_given}),
#    2851     **(extra_headers or {}),
#    2852 }
# -> 2853 return await self._post(
#    2854     "/v1/messages?beta=true",
#    2855     body=await async_maybe_transform(
#    2856         {
#    2857             "max_tokens": max_tokens,
#    2858             "messages": messages,
#    2859             "model": model,
#    2860             "container": container,
#    2861             "context_management": context_management,
#    2862             "inference_geo": inference_geo,
#    2863             "mcp_servers": mcp_servers,
#    2864             "metadata": metadata,
#    2865             "output_config": merged_output_config,
#    2866             "output_format": omit,
#    2867             "service_tier": service_tier,
#    2868             "speed": speed,
#    2869             "stop_sequences": stop_sequences,
#    2870             "stream": stream,
#    2871             "system": system,
#    2872             "temperature": temperature,
#    2873             "thinking": thinking,
#    2874             "tool_choice": tool_choice,
#    2875             "tools": tools,
#    2876             "top_k": top_k,
#    2877             "top_p": top_p,
#    2878         },
#    2879         message_create_params.MessageCreateParamsStreaming
#    2880         if stream
#    2881         else message_create_params.MessageCreateParamsNonStreaming,
#    2882     ),
#    2883     options=make_request_options(
#    2884         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2885     ),
#    2886     cast_to=BetaMessage,
#    2887     stream=stream or False,
#    2888     stream_cls=AsyncStream[BetaRawMessageStreamEvent],
#    2889 )
#
# File ~/.local/lib/python3.12/site-packages/anthropic/_base_client.py:1992, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1983     warnings.warn(
#    1984         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1985         "Please pass raw bytes via the `content` parameter instead.",
#    1986         DeprecationWarning,
#    1987         stacklevel=2,
#    1988     )
#    1989 opts = FinalRequestOptions.construct(
#    1990     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1991 )
# -> 1992 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.12/site-packages/anthropic/_base_client.py:1777, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1774             await err.response.aread()
#    1776         log.debug("Re-raising status error")
# -> 1777         raise self._make_status_error_from_response(err.response) from None
#    1779     break
#    1781 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}, 'request_id': 'req_011CayEgwkeqWWcY2x1mBg3o'}

# %% [markdown]
# ## ☁️ Infrastructure as Code — DevOps Automation
#
# LegacyBridge is moving to Azure, and the platform team wants infrastructure defined as code rather than clicked together in a portal. IaC is the difference between a hand-built snowflake server and an assembly line blueprint.
#
# With Claude, you can start from natural language requirements and quickly draft a **reviewable, version-controlled infrastructure template** that your cloud team can refine.

# %%
iac_session = agent.create_session()

iac_prompt = """
Generate a Bicep template for an Azure deployment for a trading API with:
- a Container App for the API service
- a PostgreSQL database for trade records
- a Key Vault for secrets
- a Service Bus for async order processing
- proper networking considerations
- managed identity

Please:
- use clear parameters and outputs
- include comments where helpful
- follow secure defaults suitable for an enterprise team
- return the Bicep in a single fenced code block, followed by a short explanation of the architecture
"""

response = await agent.run(iac_prompt, session=iac_session)
print(response.text)
# Out:
# ```bicep
# // =============================================================================
# // Trading API - Azure Infrastructure
# // =============================================================================
# // Architecture:
# //   Container App (API) --> PostgreSQL Flexible Server (trade records)
# //                      --> Key Vault (secrets)
# //                      --> Service Bus (async order processing)
# //
# // Networking:
# //   - Container App Environment in a dedicated subnet (delegated)
# //   - PostgreSQL in a private subnet with VNet integration
# //   - Key Vault with private endpoint
# //   - Service Bus with private endpoint
# //   - All public access disabled where possible
# // =============================================================================
#
# targetScope = 'resourceGroup'
#
# // ---------------------------------------------------------------------------
# // Parameters
# // ---------------------------------------------------------------------------
#
# @description('Short environment name used in resource naming (e.g. dev, stg, prod).')
# @allowed(['dev', 'stg', 'prod'])
# param environmentName string = 'dev'
#
# @description('Azure region for all resources.')
# param location string = resourceGroup().location
#
# @description('Name prefix applied to every resource (e.g. "trading").')
# @minLength(3)
# @maxLength(12)
# param appName string = 'trading'
#
# @description('Container image to deploy, including tag (e.g. myregistry.azurecr.io/api:1.0.0).')
# param containerImage string
#
# @description('Number of CPU cores allocated to the Container App (0.25 | 0.5 | 0.75 | 1 | ...).')
# param containerCpuCores string = '0.5'
#
# @description('Memory allocated to the Container App (e.g. "1Gi").')
# param containerMemory string = '1Gi'
#
# @description('Minimum number of Container App replicas.')
# @minValue(1)
# param minReplicas int = 1
#
# @description('Maximum number of Container App replicas.')
# @maxValue(30)
# param maxReplicas int = 5
#
# @description('PostgreSQL administrator login name.')
# @minLength(3)
# param postgresAdminLogin string = 'pgadmin'
#
# @description('PostgreSQL administrator password. Must meet Azure complexity requirements.')
# @secure()
# param postgresAdminPassword string
#
# @description('PostgreSQL SKU name (e.g. Standard_D2ds_v4).')
# param postgresSku string = 'Standard_D2ds_v4'
#
# @description('PostgreSQL storage size in MB.')
# param postgresStorageSizeMb int = 32768
#
# @description('Service Bus SKU.')
# @allowed(['Standard', 'Premium'])
# param serviceBusSku string = 'Premium' // Premium required for VNet integration
#
# @description('Object ID of the AAD group that should have Key Vault admin rights (for break-glass access).')
# param keyVaultAdminGroupObjectId string
#
# @description('Tags applied to all resources.')
# param tags object = {
#   environment: environmentName
#   application: appName
#   managedBy: 'bicep'
# }
#
# // ---------------------------------------------------------------------------
# // Variables / naming convention
# // ---------------------------------------------------------------------------
#
# var suffix = '${appName}-${environmentName}'
# var vnetName = 'vnet-${suffix}'
# var containerEnvName = 'cae-${suffix}'
# var containerAppName = 'ca-${suffix}'
# var postgresServerName = 'psql-${suffix}'
# var keyVaultName = 'kv-${suffix}' // max 24 chars; adjust appName/env accordingly
# var serviceBusNamespaceName = 'sb-${suffix}'
# var logAnalyticsName = 'law-${suffix}'
# var appInsightsName = 'appi-${suffix}'
# var managedIdentityName = 'id-${suffix}'
#
# // Subnet address spaces
# var vnetAddressPrefix = '10.0.0.0/16'
# var containerSubnetPrefix = '10.0.1.0/23' // /23 required for Container App Environments
# var postgresSubnetPrefix = '10.0.4.0/24'
# var privateEndpointSubnetPrefix = '10.0.5.0/24'
#
# // Service Bus queue names
# var ordersQueueName = 'orders'
# var ordersDlqName = 'orders-dlq'
#
# // ---------------------------------------------------------------------------
# // Managed Identity
# // ---------------------------------------------------------------------------
#
# resource managedIdentity 'Microsoft.ManagedIdentity/userAssignedIdentities@2023-01-31' = {
#   name: managedIdentityName
#   location: location
#   tags: tags
# }
#
# // ---------------------------------------------------------------------------
# // Networking
# // ---------------------------------------------------------------------------
#
# resource vnet 'Microsoft.Network/virtualNetworks@2023-09-01' = {
#   name: vnetName
#   location: location
#   tags: tags
#   properties: {
#     addressSpace: {
#       addressPrefixes: [vnetAddressPrefix]
#     }
#     subnets: [
#       {
#         // Container App Environment subnet - must be delegated
#         name: 'snet-container'
#         properties: {
#           addressPrefix: containerSubnetPrefix
#           delegations: [
#             {
#               name: 'Microsoft.App.environments'
#               properties: {
#                 serviceName: 'Microsoft.App/environments'
#               }
#             }
#           ]
#           privateEndpointNetworkPolicies: 'Disabled'
#         }
#       }
#       {
#         // PostgreSQL Flexible Server subnet - must be delegated
#         name: 'snet-postgres'
#         properties: {
#           addressPrefix: postgresSubnetPrefix
#           delegations: [
#             {
#               name: 'Microsoft.DBforPostgreSQL.flexibleServers'
#               properties: {
#                 serviceName: 'Microsoft.DBforPostgreSQL/flexibleServers'
#               }
#             }
#           ]
#           privateEndpointNetworkPolicies: 'Disabled'
#         }
#       }
#       {
#         // Private endpoints for Key Vault and Service Bus
#         name: 'snet-private-endpoints'
#         properties: {
#           addressPrefix: privateEndpointSubnetPrefix
#           privateEndpointNetworkPolicies: 'Disabled'
#         }
#       }
#     ]
#   }
# }
#
# // Convenience references to subnets
# var containerSubnetId = '${vnet.id}/subnets/snet-container'
# var postgresSubnetId = '${vnet.id}/subnets/snet-postgres'
# var privateEndpointSubnetId = '${vnet.id}/subnets/snet-private-endpoints'
#
# // Private DNS zones - required for private endpoint name resolution
# resource kvPrivateDnsZone 'Microsoft.Network/privateDnsZones@2020-06-01' = {
#   name: 'privatelink.vaultcore.azure.net'
#   location: 'global'
#   tags: tags
# }
#
# resource sbPrivateDnsZone 'Microsoft.Network/privateDnsZones@2020-06-01' = {
#   name: 'privatelink.servicebus.windows.net'
#   location: 'global'
#   tags: tags
# }
#
# resource kvDnsZoneLink 'Microsoft.Network/privateDnsZones/virtualNetworkLinks@2020-06-01' = {
#   parent: kvPrivateDnsZone
#   name: 'link-kv-${suffix}'
#   location: 'global'
#   properties: {
#     virtualNetwork: { id: vnet.id }
#     registrationEnabled: false
#   }
# }
#
# resource sbDnsZoneLink 'Microsoft.Network/privateDnsZones/virtualNetworkLinks@2020-06-01' = {
#   parent: sbPrivateDnsZone
#   name: 'link-sb-${suffix}'
#   location: 'global'
#   properties: {
#     virtualNetwork: { id: vnet.id }
#     registrationEnabled: false
#   }
# }
#
# // ---------------------------------------------------------------------------
# // Observability - Log Analytics + Application Insights
# // ---------------------------------------------------------------------------
#
# resource logAnalytics 'Microsoft.OperationalInsights/workspaces@2023-09-01' = {
#   name: logAnalyticsName
#   location: location
#   tags: tags
#   properties: {
#     sku: { name: 'PerGB2018' }
#     retentionInDays: 90
#     features: {
#       enableLogAccessUsingOnlyResourcePermissions: true
#     }
#     publicNetworkAccessForIngestion: 'Enabled' // agents need to push logs
#     publicNetworkAccessForQuery: 'Enabled'
#   }
# }
#
# resource appInsights 'Microsoft.Insights/components@2020-02-02' = {
#   name: appInsightsName
#   location: location
#   kind: 'web'
#   tags: tags
#   properties: {
#     Application_Type: 'web'
#     WorkspaceResourceId: logAnalytics.id
#     publicNetworkAccessForIngestion: 'Enabled'
#     publicNetworkAccessForQuery: 'Enabled'
#   }
# }
#
# // ---------------------------------------------------------------------------
# // Key Vault
# // ---------------------------------------------------------------------------
#
# resource keyVault 'Microsoft.KeyVault/vaults@2023-07-01' = {
#   name: keyVaultName
#   location: location
#   tags: tags
#   properties: {
#     sku: {
#       family: 'A'
#       name: 'premium' // HSM-backed keys for enterprise
#     }
#     tenantId: subscription().tenantId
#     enableRbacAuthorization: true // Use RBAC instead of legacy access policies
#     enableSoftDelete: true
#     softDeleteRetentionInDays: 90
#     enablePurgeProtection: true // Prevents accidental permanent deletion
#     publicNetworkAccess: 'Disabled' // All access via private endpoint
#     networkAcls: {
#       bypass: 'AzureServices'
#       defaultAction: 'Deny'
#     }
#   }
# }
#
# // Private endpoint for Key Vault
# resource kvPrivateEndpoint 'Microsoft.Network/privateEndpoints@2023-09-01' = {
#   name: 'pe-kv-${suffix}'
#   location: location
#   tags: tags
#   properties: {
#     subnet: { id: privateEndpointSubnetId }
#     privateLinkServiceConnections: [
#       {
#         name: 'plsc-kv-${suffix}'
#         properties: {
#           privateLinkServiceId: keyVault.id
#           groupIds: ['vault']
#         }
#       }
#     ]
#   }
# }
#
# resource kvPrivateDnsZoneGroup 'Microsoft.Network/privateEndpoints/privateDnsZoneGroups@2023-09-01' = {
#   parent: kvPrivateEndpoint
#   name: 'default'
#   properties: {
#     privateDnsZoneConfigs: [
#       {
#         name: 'privatelink-vaultcore-azure-net'
#         properties: { privateDnsZoneId: kvPrivateDnsZone.id }
#       }
#     ]
#   }
# }
#
# // RBAC: Container App managed identity -> Key Vault Secrets User
# resource kvSecretsUserRole 'Microsoft.Authorization/roleAssignments@2022-04-01' = {
#   name: guid(keyVault.id, managedIdentity.id, 'Key Vault Secrets User')
#   scope: keyVault
#   properties: {
#     roleDefinitionId: subscriptionResourceId(
#       'Microsoft.Authorization/roleDefinitions',
#       '4633458b-17de-408a-b874-0445c86b69e6' // Key Vault Secrets User
#     )
#     principalId: managedIdentity.properties.principalId
#     principalType: 'ServicePrincipal'
#   }
# }
#
# // RBAC: Break-glass admin group -> Key Vault Administrator
# resource kvAdminRole 'Microsoft.Authorization/roleAssignments@2022-04-01' = {
#   name: guid(keyVault.id, keyVaultAdminGroupObjectId, 'Key Vault Administrator')
#   scope: keyVault
#   properties: {
#     roleDefinitionId: subscriptionResourceId(
#       'Microsoft.Authorization/roleDefinitions',
#       '00482a5a-887f-4fb3-b363-3b7fe8e74483' // Key Vault Administrator
#     )
#     principalId: keyVaultAdminGroupObjectId
#     principalType: 'Group'
#   }
# }
#
# // Store the PostgreSQL password in Key Vault
# resource postgresPasswordSecret 'Microsoft.KeyVault/vaults/secrets@2023-07-01' = {
#   parent: keyVault
#   name: 'postgres-admin-password'
#   properties: {
#     value: postgresAdminPassword
#     attributes: { enabled: true }
#   }
# }
#
# // Store App Insights connection string in Key Vault
# resource appInsightsConnectionStringSecret 'Microsoft.KeyVault/vaults/secrets@2023-07-01' = {
#   parent: keyVault
#   name: 'appinsights-connection-string'
#   properties: {
#     value: appInsights.properties.ConnectionString
#     attributes: { enabled: true }
#   }
# }
#
# // ---------------------------------------------------------------------------
# // PostgreSQL Flexible Server
# // ---------------------------------------------------------------------------
#
# resource postgresServer 'Microsoft.DBforPostgreSQL/flexibleServers@2023-06-01-preview' = {
#   name: postgresServerName
#   location: location
#   tags: tags
#   sku: {
#     name: postgresSku
#     tier: 'GeneralPurpose'
#   }
#   properties: {
#     administratorLogin: postgresAdminLogin
#     administratorLoginPassword: postgresAdminPassword
#     version: '16'
#     storage: {
#       storageSizeGB: postgresStorageSizeMb / 1024
#       autoGrow: 'Enabled'
#     }
#     backup: {
#       backupRetentionDays: 35
#       geoRedundantBackup: environmentName == 'prod' ? 'Enabled' : 'Disabled'
#     }
#     highAvailability: {
#       // Zone-redundant HA only in production to control cost
#       mode: environmentName == 'prod' ? 'ZoneRedundant' : 'Disabled'
#     }
#     network: {
#       // VNet-delegated - no public access
#       delegatedSubnetResourceId: postgresSubnetId
#       privateDnsZoneArmResourceId: postgresDnsZone.id
#     }
#     authConfig: {
#       activeDirectoryAuth: 'Enabled'
#       passwordAuth: 'Enabled' // Keep password auth for migration tooling; disable after cutover if desired
#     }
#   }
#   dependsOn: [postgresDnsZoneLink]
# }
#
# // Private DNS zone for PostgreSQL (required for VNet-integrated flexible server)
# resource postgresDnsZone 'Microsoft.Network/privateDnsZones@2020-06-01' = {
#   name: '${postgresServerName}.private.postgres.database.azure.com'
#   location: 'global'
#   tags: tags
# }
#
# resource postgresDnsZoneLink 'Microsoft.Network/privateDnsZones/virtualNetworkLinks@2020-06-01' = {
#   parent: postgresDnsZone
#   name: 'link-psql-${suffix}'
#   location: 'global'
#   properties: {
#     virtualNetwork: { id: vnet.id }
#     registrationEnabled: false
#   }
# }
#
# // Trade records database
# resource tradeDatabase 'Microsoft.DBforPostgreSQL/flexibleServers/databases@2023-06-01-preview' = {
#   parent: postgresServer
#   name: 'trades'
#   properties: {
#     charset: 'UTF8'
#     collation: 'en_US.utf8'
#   }
# }
#
# // Store the connection string in Key Vault
# resource postgresConnectionStringSecret 'Microsoft.KeyVault/vaults/secrets@2023-07-01' = {
#   parent: keyVault
#   name: 'postgres-connection-string'
#   properties: {
#     value: 'Host=${postgresServer.properties.fullyQualifiedDomainName};Database=trades;Username=${postgresAdminLogin};Password=${postgresAdminPassword};SslMode=Require'
#     attributes: { enabled: true }
#   }
# }
#
# // ---------------------------------------------------------------------------
# // Service Bus
# // ---------------------------------------------------------------------------
#
# resource serviceBusNamespace 'Microsoft.ServiceBus/namespaces@2022-10-01-preview' = {
#   name: serviceBusNamespaceName
#   location: location
#   tags: tags
#   sku: {
#     name: serviceBusSku
#     tier: serviceBusSku
#     capacity: 1
#   }
#   properties: {
#     minimumTlsVersion: '1.2'
#     publicNetworkAccess: 'Disabled' // All access via private endpoint
#     disableLocalAuth:

# %% [markdown]
# ## 🎯 Try It Yourself
#
# Now it's your turn to treat Claude like a modernization teammate.
#
# ### Suggested exercises
# 1. Take a real function from your codebase and ask Claude for a review focused on bugs, security, and maintainability.
# 2. Translate a small snippet from one language to another and ask Claude to explain what changed semantically, not just syntactically.
# 3. Generate tests for an untested module before refactoring it.
# 4. Draft IaC from a whiteboard-style requirements list, then refine it with your platform team's standards.
#
# ### Key takeaways
# - **Specific prompts produce better code.** Think like you're writing a ticket for a senior engineer.
# - **Sessions unlock iteration.** You can refine code step by step instead of reprompting from zero.
# - **Claude is useful across the software lifecycle.** Not just coding, but reviewing, translating, testing, and infrastructure design.
# - **Foundry gives you a deployment-ready path.** The same model you test in a playground can be wired into production code through the Agent Framework.
#
# If LegacyBridge can modernize a 20-year-old trading platform one component at a time, your team can too.
